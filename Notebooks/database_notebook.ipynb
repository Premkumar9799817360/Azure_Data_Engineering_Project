# %% [markdown]
# # Create Catalog

# %%
# %sql
CREATE CATALOG car_catalog;

# %% [markdown]
# ## Create Schema

# %%
# %sql 
CREATE SCHEMA car_catalog.silver;

# %%
# %sql
CREATE SCHEMA car_catalog.gold;
